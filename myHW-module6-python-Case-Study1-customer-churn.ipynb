# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
#HOMEWORK MODULE 6 - MATPLOTLIB -Case Study1) import customer_churn.csv
# a) bar plot for column 'contract':

# %%
#customer_churn.csv

df=pd.read_csv('customer_churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df['Contract'].value_counts()
# Out:
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64

# %%
df['Contract'].unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
contract_df=df['Contract'].value_counts()

contract_df
# Out:
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64

# %%
# 4 tasks to perform
#Task 1: barplot for Contract column

x=['Month-to-month', 'One year', 'Two year']

y=[3875,695,1473]
plt.bar(x, y, color='orange')
plt.xlabel('Contract type of Customer')
plt.ylabel('Count')
plt.title('Distribution of Contract')

plt.show()

# %%
#Task 2: histogram 'Monthly Charges':

x=df['MonthlyCharges']

plt.hist(x, bins=30, histtype='bar', align='mid',  color='c', edgecolor='black')
#plt.hist(x, bins=30, histtype='bar', align='mid', color='c', edgecolor='black')
#plt.legend()

plt.xlabel('Monthly Charges incured')
plt.ylabel('Count')

plt.title('Distribution of Monthly Charges')
plt.show()

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# Task3: scatter plot between "Total CHarges" and 'Tenure':
x=df['TotalCharges']
y=df['tenure']

plt.scatter(x,y, marker='*')
plt.show()

# %%
plt.figure(figsize=(10,16))
x5=df['tenure']
y5=df['TotalCharges']
plt.xlabel('Tenure of the Customer')
plt.ylabel('Total Charges Incured')
plt.title('Total CHarges vs Tenure')
plt.yticks(rotation=90)
plt.scatter(x5,y5, marker='*', c='indigo')
plt.show()

# %%
#task4: boxplot between 'MonthlyCharges' and 'PaymentMethod':

df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
mmm=df['MonthlyCharges']
mmm
# Out:
# 0        29.85
# 1        56.95
# 2        53.85
# 3        42.30
# 4        70.70
#          ...
# 7038     84.80
# 7039    103.20
# 7040     29.60
# 7041     74.40
# 7042    105.65
# Name: MonthlyCharges, Length: 7043, dtype: float64

# %%
df['PaymentMethod'].unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
df['PaymentMethod'].value_counts()
# Out:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %%
a1=df[(df['PaymentMethod']=='Electronic check') & (df['MonthlyCharges'])]
a1
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 8     7892-POOKP  Female              0     Yes         No      28
# 14    5129-JLPIS    Male              0      No         No      25
# ...          ...     ...            ...     ...        ...     ...
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7029  2235-DWLJU  Female              1      No         No       6
# 7032  6894-LFHLY    Male              1      No         No       1
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
a1['MonthlyCharges']
# Out:
# 0        29.85
# 4        70.70
# 5        99.65
# 8       104.80
# 14      105.50
#          ...
# 7023    103.50
# 7029     44.40
# 7032     75.75
# 7036     60.65
# 7040     29.60
# Name: MonthlyCharges, Length: 2365, dtype: float64

# %%
a2=df[(df['PaymentMethod']=='Mailed check') & (df['MonthlyCharges'])]
a2
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 7     6713-OKOMC  Female              0      No         No      10
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 16    8191-XWSZG  Female              0      No         No      52
# ...          ...     ...            ...     ...        ...     ...
# 7019  9710-NJERN  Female              0      No         No      39
# 7027  0550-DCXLH    Male              0      No         No      13
# 7030  0871-OPBXW  Female              0      No         No       2
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 1             Yes                No             DSL                  Yes  ...
# ...

# %%
a2['MonthlyCharges']
# Out:
# 1       56.95
# 2       53.85
# 7       29.75
# 10      49.95
# 16      20.65
#         ...
# 7019    20.15
# 7027    73.35
# 7030    20.05
# 7038    84.80
# 7041    74.40
# Name: MonthlyCharges, Length: 1612, dtype: float64

# %%
a3=df[(df['PaymentMethod']=='Bank transfer (automatic)') & (df['MonthlyCharges'])]
a3
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3     7795-CFOCW    Male              0      No         No      45
# 9     6388-TABGU    Male              0      No        Yes      62
# 13    0280-XJGEX    Male              0      No         No      49
# 17    9959-WOFKT    Male              0      No        Yes      71
# 21    1680-VDCWW    Male              0     Yes         No      12
# ...          ...     ...            ...     ...        ...     ...
# 7026  8775-CEBBJ  Female              0      No         No       9
# 7028  9281-CEDRU  Female              0     Yes         No      68
# 7035  8456-QDAVC    Male              0      No         No      19
# 7037  2569-WGERO  Female              0      No         No      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 3              No  No phone service             DSL                  Yes  ...
# ...

# %%
a3['MonthlyCharges']
# Out:
# 3        42.30
# 9        56.15
# 13      103.70
# 17      106.70
# 21       19.80
#          ...
# 7026     44.20
# 7028     64.10
# 7035     78.70
# 7037     21.15
# 7042    105.65
# Name: MonthlyCharges, Length: 1544, dtype: float64

# %%
#Credit card (automatic)
a4=df[(df['PaymentMethod']=='Credit card (automatic)') & (df['MonthlyCharges'])]
a4
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 6     1452-KIOVK    Male              0      No        Yes      22
# 11    7469-LKBCI    Male              0      No         No      16
# 12    8091-TTVAX    Male              0     Yes         No      58
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 18    4190-MFLUW  Female              0     Yes        Yes      10
# ...          ...     ...            ...     ...        ...     ...
# 7024  7398-LXGYX    Male              0     Yes         No      44
# 7031  3605-JISKB    Male              1     Yes         No      55
# 7033  9767-FFLEM    Male              0      No         No      38
# 7034  0639-TSIQW  Female              0      No         No      67
# 7039  2234-XADUH  Female              0     Yes        Yes      72
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 6             Yes           Yes     Fiber optic                   No  ...
# ...

# %%
a4['MonthlyCharges']
# Out:
# 6        89.10
# 11       18.95
# 12      100.35
# 15      113.25
# 18       55.20
#          ...
# 7024     84.80
# 7031     60.00
# 7033     69.50
# 7034    102.95
# 7039    103.20
# Name: MonthlyCharges, Length: 1522, dtype: float64

# %%
#task 4: box plot between "Monthly Charges" and "Payment Method":

# Create box plot in python with fills and labels
#Electronic check             2365
#Mailed check                 1612
#Bank transfer (automatic)    1544
#Credit card (automatic)      1522

value1 = a1['MonthlyCharges']   #Electronic check             2365

value2 = a2['MonthlyCharges']   #Mailed check                 1612

value3 = a3['MonthlyCharges']   #Bank transfer (automatic)    1544

value4 = a4['MonthlyCharges']   #Credit card (automatic)      1522

box_plot_data = [value1, value2, value3, value4]
#'MonthlyCharges']
#'PaymentMethod']

box_plot_data = [value1,value2,value3,value4]
plt.xlabel('Payment Method of Customer')
plt.ylabel('MonthlyCharges Incured (in US$)')
plt.title('Monthly Charges vs Payment Method')

box=plt.boxplot(box_plot_data, patch_artist=True,labels=[
            'Electronic check', 'Mailed check', 'Bank transfer', 'Credit card'])
#colors = ['green', 'tan', 'olive', 'cyan']
colors = ['olive','olive','olive','olive']
for patch, color in zip(box['boxes'], colors):
    patch.set_facecolor(color)

plt.show()
