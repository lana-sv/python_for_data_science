# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('customer_churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
#df.iloc[0:6]

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
#task2:
#df.loc[[3,7,9,20]]
df.loc[[2,6,8,19]]
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 6   1452-KIOVK    Male              0      No        Yes      22          Yes
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 19  4183-MYFRB  Female              0      No         No      21          Yes
#
#    MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 2             No             DSL            Yes  ...               No
# 6            Yes     Fiber optic             No  ...               No
# 8            Yes     Fiber optic             No  ...              Yes
# 19            No     Fiber optic             No  ...              Yes
#
#    TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 2           No          No              No  Month-to-month              Yes
# ...

# %%
df.loc[0:,['SeniorCitizen','PhoneService','InternetService','MonthlyCharges']]


# df.loc[:,['SeniorCitizen','PhoneService','InternetService','MonthlyCharges']]
# Out:
#       SeniorCitizen PhoneService InternetService  MonthlyCharges
# 0                 0           No             DSL           29.85
# 1                 0          Yes             DSL           56.95
# 2                 0          Yes             DSL           53.85
# 3                 0           No             DSL           42.30
# 4                 0          Yes     Fiber optic           70.70
# ...             ...          ...             ...             ...
# 7038              0          Yes             DSL           84.80
# 7039              0          Yes     Fiber optic          103.20
# 7040              0           No             DSL           29.60
# 7041              1          Yes     Fiber optic           74.40
# 7042              0          Yes     Fiber optic          105.65
#
# [7043 rows x 4 columns]

# %%
df.iloc[:,[2,6,8,19]]
# Out:
#       SeniorCitizen PhoneService InternetService TotalCharges
# 0                 0           No             DSL        29.85
# 1                 0          Yes             DSL       1889.5
# 2                 0          Yes             DSL       108.15
# 3                 0           No             DSL      1840.75
# 4                 0          Yes     Fiber optic       151.65
# ...             ...          ...             ...          ...
# 7038              0          Yes             DSL       1990.5
# 7039              0          Yes     Fiber optic       7362.9
# 7040              0           No             DSL       346.45
# 7041              1          Yes     Fiber optic        306.6
# 7042              0          Yes     Fiber optic       6844.5
#
# [7043 rows x 4 columns]

# %%
df_seniors= df.iloc[:,[2,6,8,19]]
df_seniors
# Out:
#       SeniorCitizen PhoneService InternetService TotalCharges
# 0                 0           No             DSL        29.85
# 1                 0          Yes             DSL       1889.5
# 2                 0          Yes             DSL       108.15
# 3                 0           No             DSL      1840.75
# 4                 0          Yes     Fiber optic       151.65
# ...             ...          ...             ...          ...
# 7038              0          Yes             DSL       1990.5
# 7039              0          Yes     Fiber optic       7362.9
# 7040              0           No             DSL       346.45
# 7041              1          Yes     Fiber optic        306.6
# 7042              0          Yes     Fiber optic       6844.5
#
# [7043 rows x 4 columns]

# %%
#df3=df_seniors
#df3

# %%
# how to rename columns???
#df.rename(columns={"A": "a", "B": "b", "C": "c"}, errors="raise")
df_seniors= df3.rename(columns={'SeniorCitizen':'senior','PhoneService':'phone-S',
                      'InternetService':'internet','MonthlyCharges':'monthly-charge'})
df_seniors
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-a61b105cb2a6> in <module>
#       1 # how to rename columns???
#       2 #df.rename(columns={"A": "a", "B": "b", "C": "c"}, errors="raise")
# ----> 3 df_seniors= df3.rename(columns={'SeniorCitizen':'senior','PhoneService':'phone-S',
#       4                       'InternetService':'internet','MonthlyCharges':'monthly-charge'})
#       5 df_seniors
#
# NameError: name 'df3' is not defined

# %%
#Assignment 2 of Module 5:
#task3 of Assignment 1 of Module 5:

df.iloc[200:1001]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 200   9323-HGFWY  Female              0     Yes         No      27
# 201   8544-GOQSH  Female              0      No         No      14
# 202   3363-DTIVD    Male              0     Yes        Yes      71
# 203   7018-WBJNK    Male              0      No        Yes      13
# 204   9142-KZXOP    Male              0      No         No      44
# ...          ...     ...            ...     ...        ...     ...
# 996   6641-XRPSU  Female              0      No         No      34
# 997   1374-DMZUI  Female              1      No         No       4
# 998   2545-LXYVJ    Male              0     Yes         No      72
# 999   3234-VKACU    Male              0      No         No       2
# 1000  8357-EQXFO  Female              0      No         No       7
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 200           Yes            No     Fiber optic                  Yes  ...
# ...

# %%
#Assignment 2 of Module 5:
#task4 of Assignment 1 of Module 5::

#df.iloc[1:16,200:1001]

df.iloc[200:1001,2:16]
# Out:
#       SeniorCitizen Partner Dependents  tenure PhoneService MultipleLines  \
# 200               0     Yes         No      27          Yes            No
# 201               0      No         No      14          Yes            No
# 202               0     Yes        Yes      71          Yes           Yes
# 203               0      No        Yes      13          Yes            No
# 204               0      No         No      44          Yes            No
# ...             ...     ...        ...     ...          ...           ...
# 996               0      No         No      34          Yes            No
# 997               1      No         No       4          Yes           Yes
# 998               0     Yes         No      72          Yes            No
# 999               0      No         No       2          Yes            No
# 1000              0      No         No       7          Yes            No
#
#      InternetService       OnlineSecurity         OnlineBackup  \
# ...

# %%
#task5:

df.head(100)
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 1   5575-GNVDE    Male              0      No         No      34          Yes
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 3   7795-CFOCW    Male              0      No         No      45           No
# 4   9237-HQITU  Female              0      No         No       2          Yes
# ..         ...     ...            ...     ...        ...     ...          ...
# 95  8637-XJIVR  Female              0      No         No      12          Yes
# 96  9803-FTJCG    Male              0     Yes        Yes      71          Yes
# 97  0278-YXOOG    Male              0      No         No       5          Yes
# 98  3212-KXOCR    Male              0      No         No      52          Yes
# 99  4598-XLKNJ  Female              1     Yes         No      25          Yes
#
# ...

# %%
#task6:
df.tail(10)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7033  9767-FFLEM    Male              0      No         No      38
# 7034  0639-TSIQW  Female              0      No         No      67
# 7035  8456-QDAVC    Male              0      No         No      19
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7037  2569-WGERO  Female              0      No         No      72
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 7033          Yes                No     Fiber optic                   No  ...
# ...

# %%
#task7:
df.tail(1)
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 7042  3186-AJIEK   Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 7042          Yes            No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  Contract  \
# 7042              Yes         Yes         Yes             Yes  Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 7042    No
#
# [1 rows x 21 columns]

# %%
#task8:
df4=df.sort_values(by='tenure',ascending=False)
df4
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1672  4737-AQCPU    Male              0     Yes        Yes      72
# 193   9680-NIAUV  Female              0     Yes        Yes      72
# 4553  5914-XRFQB    Male              0     Yes         No      72
# 483   5168-MQQCA  Female              0     Yes         No      72
# 3266  0464-WJTKO  Female              0     Yes        Yes      72
# ...          ...     ...            ...     ...        ...     ...
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 1672          Yes               Yes             DSL                  Yes  ...
# ...

# %%
df.tenure
# Out:
# 0        1
# 1       34
# 2        2
# 3       45
# 4        2
#         ..
# 7038    24
# 7039    72
# 7040    11
# 7041     4
# 7042    66
# Name: tenure, Length: 7043, dtype: int64

# %%
df.tenure.unique()
# Out:
# array([ 1, 34,  2, 45,  8, 22, 10, 28, 62, 13, 16, 58, 49, 25, 69, 52, 71,
#        21, 12, 30, 47, 72, 17, 27,  5, 46, 11, 70, 63, 43, 15, 60, 18, 66,
#         9,  3, 31, 50, 64, 56,  7, 42, 35, 48, 29, 65, 38, 68, 32, 55, 37,
#        36, 41,  6,  4, 33, 67, 23, 57, 61, 14, 20, 53, 40, 59, 24, 44, 19,
#        54, 51, 26,  0, 39])

# %%
len(df.tenure.unique())
# Out:
# 73

# %%
df.tenure.value_counts()
# Out:
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: tenure, Length: 73, dtype: int64

# %%
#task9:
'''
Fetch all the records that are satisfying the following condition:
a. Tenure>50 and the gender as ‘Female’.
b. Gender as ‘Male’ and SeniorCitizen as 0.
c. TechSupport as ‘Yes’ and Churn as ‘No’.
d. Contract type as ‘Month-to-month’ and Churn as ‘Yes’.
10. Use a for loop to calculate the number of customers
that are getting the tech support and are male senior citizen.
'''
# Out:
# '\nFetch all the records that are satisfying the following condition:\na. Tenure>50 and the gender as ‘Female’.\nb. Gender as ‘Male’ and SeniorCitizen as 0.\nc. TechSupport as ‘Yes’ and Churn as ‘No’.\nd. Contract type as ‘Month-to-month’ and Churn as ‘Yes’.\n10. Use a for loop to calculate the number of customers\nthat are getting the tech support and are male senior citizen.\n'

# %%
#df5=df[df['tenure']>50 and df['gender']=='Female']

df5=df[df.tenure>50]  #and df.gender='Female']

df5
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 9     6388-TABGU    Male              0      No        Yes      62
# 12    8091-TTVAX    Male              0     Yes         No      58
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 16    8191-XWSZG  Female              0      No         No      52
# 17    9959-WOFKT    Male              0      No        Yes      71
# ...          ...     ...            ...     ...        ...     ...
# 7031  3605-JISKB    Male              1     Yes         No      55
# 7034  0639-TSIQW  Female              0      No         No      67
# 7037  2569-WGERO  Female              0      No         No      72
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 9             Yes            No             DSL                  Yes  ...
# ...

# %%
#filter1 = df[(df.tenure>50) & (df.gender == 'Female')]
#filter2 = df[(df.tenure>50) & (df.gender == 'Female')]


df6=df[(df.tenure>50) & (df.gender == 'Female')]


#df[(df['TotalMarks'] > 50) & (df['TotalMarks'] < 80) ]

df6
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 16    8191-XWSZG  Female              0      No         No      52
# 23    3638-WEABW  Female              0     Yes         No      58
# 30    3841-NFECX  Female              1     Yes         No      71
# 35    6234-RAAPL  Female              0     Yes        Yes      72
# ...          ...     ...            ...     ...        ...     ...
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7028  9281-CEDRU  Female              0     Yes         No      68
# 7034  0639-TSIQW  Female              0      No         No      67
# 7037  2569-WGERO  Female              0      No         No      72
# 7039  2234-XADUH  Female              0     Yes        Yes      72
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 15            Yes           Yes     Fiber optic                  Yes  ...
# ...

# %%
'''
Fetch all the records that are satisfying the following condition:
a. Tenure>50 and the gender as ‘Female’.
b. Gender as ‘Male’ and SeniorCitizen as 0.
c. TechSupport as ‘Yes’ and Churn as ‘No’.
d. Contract type as ‘Month-to-month’ and Churn as ‘Yes’.
10. Use a for loop to calculate the number of customers
that are getting the tech support and are male senior citizen.
'''

df7=df[(df.SeniorCitizen==0) & (df.gender == 'Male')]
df7
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE   Male              0      No         No      34
# 2     3668-QPYBK   Male              0      No         No       2
# 3     7795-CFOCW   Male              0      No         No      45
# 6     1452-KIOVK   Male              0      No        Yes      22
# 9     6388-TABGU   Male              0      No        Yes      62
# ...          ...    ...            ...     ...        ...     ...
# 7027  0550-DCXLH   Male              0      No         No      13
# 7033  9767-FFLEM   Male              0      No         No      38
# 7035  8456-QDAVC   Male              0      No         No      19
# 7038  6840-RESVB   Male              0     Yes        Yes      24
# 7042  3186-AJIEK   Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1             Yes                No             DSL            Yes  ...
# ...

# %%
#TechSupport as ‘Yes’ and Churn as ‘No’.
df8=df[(df.TechSupport=='Yes') & (df.Churn == 'No')]
df8
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3     7795-CFOCW    Male              0      No         No      45
# 14    5129-JLPIS    Male              0      No         No      25
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 23    3638-WEABW  Female              0     Yes         No      58
# 24    6322-HRPFA    Male              0     Yes        Yes      49
# ...          ...     ...            ...     ...        ...     ...
# 7027  0550-DCXLH    Male              0      No         No      13
# 7028  9281-CEDRU  Female              0     Yes         No      68
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 3              No  No phone service             DSL            Yes  ...
# ...

# %%
#Contract type as ‘Month-to-month’ and Churn as ‘Yes’.

df9=df[(df.Contract=='Month-to-month') & (df.Churn == 'Yes')]
df9
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2     3668-QPYBK    Male              0      No         No       2
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 8     7892-POOKP  Female              0     Yes         No      28
# 13    0280-XJGEX    Male              0      No         No      49
# ...          ...     ...            ...     ...        ...     ...
# 7018  1122-JWTJW    Male              0     Yes        Yes       1
# 7026  8775-CEBBJ  Female              0      No         No       9
# 7032  6894-LFHLY    Male              1      No         No       1
# 7034  0639-TSIQW  Female              0      No         No      67
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 2             Yes            No             DSL            Yes  ...
# ...

# %%
#Use a for loop to calculate the number of customers
#that are getting the tech support and are male senior citizen.


df7a_count=df[(df.SeniorCitizen==1) & (df.gender == 'Male')]

df7a_count
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 20    8779-QRDMV   Male              1      No         No       1
# 31    4929-XIHVW   Male              1     Yes         No       2
# 34    3413-BMNZE   Male              1      No         No       1
# 55    1658-BYGOY   Male              1      No         No      18
# 57    5067-XJQFU   Male              1     Yes        Yes      66
# ...          ...    ...            ...     ...        ...     ...
# 7007  2274-XUATA   Male              1     Yes         No      72
# 7015  0666-UXTJO   Male              1     Yes         No      34
# 7031  3605-JISKB   Male              1     Yes         No      55
# 7032  6894-LFHLY   Male              1      No         No       1
# 7041  8361-LTMKD   Male              1     Yes         No       4
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 20             No  No phone service             DSL             No  ...
# ...

# %%
#Assignment 3 of Module 5:
#task 1:

#display top 100 records from dataset:

df.iloc[0:101]
# Out:
#      customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0    7590-VHVEG  Female              0     Yes         No       1
# 1    5575-GNVDE    Male              0      No         No      34
# 2    3668-QPYBK    Male              0      No         No       2
# 3    7795-CFOCW    Male              0      No         No      45
# 4    9237-HQITU  Female              0      No         No       2
# ..          ...     ...            ...     ...        ...     ...
# 96   9803-FTJCG    Male              0     Yes        Yes      71
# 97   0278-YXOOG    Male              0      No         No       5
# 98   3212-KXOCR    Male              0      No         No      52
# 99   4598-XLKNJ  Female              1     Yes         No      25
# 100  6380-ARCEH    Male              0      No         No       1
#
#     PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 0             No  No phone service             DSL                   No  ...
# ...

# %%
#Assignment 3 of Module 5:
#task 2:

#display last 10 records from dataset:
df.tail(10)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7033  9767-FFLEM    Male              0      No         No      38
# 7034  0639-TSIQW  Female              0      No         No      67
# 7035  8456-QDAVC    Male              0      No         No      19
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7037  2569-WGERO  Female              0      No         No      72
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 7033          Yes                No     Fiber optic                   No  ...
# ...

# %%
df.tail(1)
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 7042  3186-AJIEK   Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 7042          Yes            No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  Contract  \
# 7042              Yes         Yes         Yes             Yes  Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 7042    No
#
# [1 rows x 21 columns]

# %%
#Assignment 4 of Module 5:
#task 1:

#sort data by tenure column in descending order:

df_tenure_desc = df.sort_values(by='tenure',ascending=False)

df_tenure_desc
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1672  4737-AQCPU    Male              0     Yes        Yes      72
# 193   9680-NIAUV  Female              0     Yes        Yes      72
# 4553  5914-XRFQB    Male              0     Yes         No      72
# 483   5168-MQQCA  Female              0     Yes         No      72
# 3266  0464-WJTKO  Female              0     Yes        Yes      72
# ...          ...     ...            ...     ...        ...     ...
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 1672          Yes               Yes             DSL                  Yes  ...
# ...

# %%
#Assignment 4 of Module 5:
#task 2a:

# a)tenure>50 and gender=Female:

df_t50_females=df[(df.tenure>50) & (df.gender == 'Female')]

df_t50_females
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 16    8191-XWSZG  Female              0      No         No      52
# 23    3638-WEABW  Female              0     Yes         No      58
# 30    3841-NFECX  Female              1     Yes         No      71
# 35    6234-RAAPL  Female              0     Yes        Yes      72
# ...          ...     ...            ...     ...        ...     ...
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7028  9281-CEDRU  Female              0     Yes         No      68
# 7034  0639-TSIQW  Female              0      No         No      67
# 7037  2569-WGERO  Female              0      No         No      72
# 7039  2234-XADUH  Female              0     Yes        Yes      72
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 15            Yes           Yes     Fiber optic                  Yes  ...
# ...

# %%
df_t50_females_sorted = df_t50_females.sort_values(by='tenure',ascending=False)

df_t50_females_sorted
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 4574  8999-XXGNS  Female              1     Yes         No      72
# 4872  8125-QPFJD  Female              0     Yes         No      72
# 4801  0988-AADSA  Female              0     Yes        Yes      72
# 2915  0301-FIDRB  Female              0     Yes        Yes      72
# ...          ...     ...            ...     ...        ...     ...
# 1090  9036-CSKBW  Female              0      No         No      51
# 5408  6407-GSJNL  Female              0      No         No      51
# 3648  9419-IPPBE  Female              0     Yes        Yes      51
# 1935  7297-DVYGA  Female              0      No         No      51
# 3832  4626-OZDTJ  Female              0     Yes         No      51
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 7039          Yes               Yes     Fiber optic                   No  ...
# ...

# %%
#Assignment 4 of Module 5:
#task 2b:

# b) tsenior sitizen=0 and gender=male:

df7_nonsenior_males=df[(df.SeniorCitizen==0) & (df.gender == 'Male')]

df7_nonsenior_males
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE   Male              0      No         No      34
# 2     3668-QPYBK   Male              0      No         No       2
# 3     7795-CFOCW   Male              0      No         No      45
# 6     1452-KIOVK   Male              0      No        Yes      22
# 9     6388-TABGU   Male              0      No        Yes      62
# ...          ...    ...            ...     ...        ...     ...
# 7027  0550-DCXLH   Male              0      No         No      13
# 7033  9767-FFLEM   Male              0      No         No      38
# 7035  8456-QDAVC   Male              0      No         No      19
# 7038  6840-RESVB   Male              0     Yes        Yes      24
# 7042  3186-AJIEK   Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1             Yes                No             DSL            Yes  ...
# ...

# %%
df7_nonsenior_males.sort_values(by='tenure',ascending=False)
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 3466  9430-NKQLY   Male              0     Yes        Yes      72
# 485   7971-HLVXI   Male              0     Yes        Yes      72
# 4216  2990-IAJSV   Male              0      No         No      72
# 4215  9031-ZVQPT   Male              0     Yes         No      72
# 4170  0906-QVPMS   Male              0     Yes         No      72
# ...          ...    ...            ...     ...        ...     ...
# 5218  2923-ARZLG   Male              0     Yes        Yes       0
# 3826  3213-VVOLG   Male              0     Yes        Yes       0
# 3331  7644-OMVMY   Male              0     Yes        Yes       0
# 1082  4367-NUYAO   Male              0     Yes        Yes       0
# 753   3115-CZMZD   Male              0      No        Yes       0
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 3466          Yes           Yes              No  No internet service  ...
# ...

# %%
#Assignment 4 of Module 5:
#task 2c:

#tech support yes, churn no:

df_support_nonchurn = df[(df.TechSupport=='Yes') & (df.Churn == 'No')]

df_support_nonchurn
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3     7795-CFOCW    Male              0      No         No      45
# 14    5129-JLPIS    Male              0      No         No      25
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 23    3638-WEABW  Female              0     Yes         No      58
# 24    6322-HRPFA    Male              0     Yes        Yes      49
# ...          ...     ...            ...     ...        ...     ...
# 7027  0550-DCXLH    Male              0      No         No      13
# 7028  9281-CEDRU  Female              0     Yes         No      68
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 3              No  No phone service             DSL            Yes  ...
# ...

# %%
#Assignment 4 of Module 5:
#task 2d:

#contract type month-to-month, churn yes:

df_churn_contract=df[(df.Contract=='Month-to-month') & (df.Churn == 'Yes')]

df_churn_contract
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2     3668-QPYBK    Male              0      No         No       2
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 8     7892-POOKP  Female              0     Yes         No      28
# 13    0280-XJGEX    Male              0      No         No      49
# ...          ...     ...            ...     ...        ...     ...
# 7018  1122-JWTJW    Male              0     Yes        Yes       1
# 7026  8775-CEBBJ  Female              0      No         No       9
# 7032  6894-LFHLY    Male              1      No         No       1
# 7034  0639-TSIQW  Female              0      No         No      67
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 2             Yes            No             DSL            Yes  ...
# ...

# %%
#Assignment 5 of Module 5:
#task 1 and only:

#use loop to calculate number of customers that getting tech support and male seniors:

df_males_seniors_techsupported = df[(df.TechSupport=='Yes') & (df.gender == 'Male') & (df.SeniorCitizen==1)]

df_males_seniors_techsupported
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 57    5067-XJQFU   Male              1     Yes        Yes      66
# 72    1891-QRQSA   Male              1     Yes        Yes      64
# 91    2424-WVHPL   Male              1      No         No       1
# 273   4716-HHKQH   Male              1     Yes         No      20
# 382   8204-YJCLA   Male              1     Yes        Yes      72
# ...          ...    ...            ...     ...        ...     ...
# 6601  4909-JOUPP   Male              1     Yes         No      72
# 6605  7632-MNYOY   Male              1      No         No      66
# 6763  7471-MQPOS   Male              1     Yes        Yes      71
# 6956  2451-YMUXS   Male              1      No         No      67
# 7007  2274-XUATA   Male              1     Yes         No      72
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 57            Yes               Yes     Fiber optic             No  ...
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
cols = df.columns

type(cols)
# Out:
# pandas.core.indexes.base.Index

# %%
columns = ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
       'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn']

# %%
type(columns)
# Out:
# list

# %%
#use loop to calculate number of customers that getting tech support and male seniors:
'''
columns = ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
       'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
       'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
       'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
       'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn']
       
       '''
columns = ['gender', 'SeniorCitizen', 'TechSupport']
for i in columns:               # iterate on values in a list
    if i is not None:   # as long as its an acceptable value
      #for year_num in range(1, 6):      # split by years
        for i in range(0, 3):
    
        # filter and make intermediate df based on per value & per year calculation
        #cond_1 = df[f'{kip}'].str.contains(re.escape(str(val)), na=False)
        #cond_2 = df[f'{kip}'].notna()
       # cond_3 = df['Date'].dt.year < 2015 + year_num
        #cond_4 = df['Date'].dt.year >= 2015 + year_num -1
            cond_1 =  df.TechSupport=='Yes'
            cond_2 =  df.gender == 'Male'
            cond_3 = df.SeniorCitizen==1

        temp_df = df[cond_1 & cond_2 & cond_3]
        
temp_df
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 57    5067-XJQFU   Male              1     Yes        Yes      66
# 72    1891-QRQSA   Male              1     Yes        Yes      64
# 91    2424-WVHPL   Male              1      No         No       1
# 273   4716-HHKQH   Male              1     Yes         No      20
# 382   8204-YJCLA   Male              1     Yes        Yes      72
# ...          ...    ...            ...     ...        ...     ...
# 6601  4909-JOUPP   Male              1     Yes         No      72
# 6605  7632-MNYOY   Male              1      No         No      66
# 6763  7471-MQPOS   Male              1     Yes        Yes      71
# 6956  2451-YMUXS   Male              1      No         No      67
# 7007  2274-XUATA   Male              1     Yes         No      72
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 57            Yes               Yes     Fiber optic             No  ...
# ...

# %%
#use loop to calculate number of customers that getting tech support and male seniors:

columns = ['gender', 'SeniorCitizen', 'TechSupport']
for i in columns:               
    if i is not None:   
           
        for i in range(0, 3):
    
            cond_1 =  df.TechSupport=='Yes'
            cond_2 =  df.gender == 'Male'
            cond_3 = df.SeniorCitizen==1

        tempp_df = df[cond_1 & cond_2 & cond_3]
        
tempp_df
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 57    5067-XJQFU   Male              1     Yes        Yes      66
# 72    1891-QRQSA   Male              1     Yes        Yes      64
# 91    2424-WVHPL   Male              1      No         No       1
# 273   4716-HHKQH   Male              1     Yes         No      20
# 382   8204-YJCLA   Male              1     Yes        Yes      72
# ...          ...    ...            ...     ...        ...     ...
# 6601  4909-JOUPP   Male              1     Yes         No      72
# 6605  7632-MNYOY   Male              1      No         No      66
# 6763  7471-MQPOS   Male              1     Yes        Yes      71
# 6956  2451-YMUXS   Male              1      No         No      67
# 7007  2274-XUATA   Male              1     Yes         No      72
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 57            Yes               Yes     Fiber optic             No  ...
# ...
